# %% [markdown]
# # Numpy basics

# %% [markdown]
# ### Creatings Numpy Array

# %%
import numpy as nmpy
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
testList =[1,2,3,4,5,6]
testArray =  nmpy.array(testList)

# %%
var1 = ('1 2;3 4;5 7;2 4')

# a will make an array from which we can print index value
a = nmpy.mat(var1)
# b will make an array from which we can print index values
b = nmpy.array(a)
# c will not make an array from which we can take out index , it will be just all the values.
c = nmpy.array(var1)

# %% [markdown]
# ## Typecasting
# * <u6 or <u15 = restrict to 6 digits or character or any np. definde
# * complex etc

# %%
d = nmpy.array([1,2,43,4], dtype='float')

# %%
d.dtype
# Out:
# dtype('float64')

# %%
e = nmpy.array([('Sunny', 30, 30000.0),('Bunny' ,20 ,10000), ('Honey', 28 ,12000)], dtype=[('Name','U10'),('Age','int32'),('Salary','f4')] )
e
# Out:
# array([('Sunny', 30, 30000.), ('Bunny', 20, 10000.),
#        ('Honey', 28, 12000.)],
#       dtype=[('Name', '<U10'), ('Age', '<i4'), ('Salary', '<f4')])

# %% [markdown]
# ## Shape, size, Dimention, range, arange, reshape, max,slice, index,ravel,size,

# %%
f = nmpy.array([(1,2, 3), (11, 9, 7), (4, 5, 6),(44, 52, 62)])

# give shape ex (4,3)
g = f.shape
print(g)
# shape[0] = means how many rows = 4
#and shape[1] = how many columns = 3
h = f.shape[1]
# shows the dimention
i = f.ndim
print(i)
# size will show u total no. of elements
i = f.size
print(i)
# makes array of ones in shape of 4 by 3
i = nmpy.ones((4,3))
# range from 0 till 1o
list(range(10))

# make an array, Start, Stop,interval
i = list(nmpy.arange(5,50,2))
# same as range, start, stop and the last means total no. of values to be displayed with the equal distance to each space. 
i= nmpy.linspace(5,50,4)
#reshape((-1,4) means it moulds into four columns and according to that remaining rows will be decided automatically,
#-1 means unknown
i = nmpy.random.randint(5,150,21).reshape(-1,3)
# arguments, start,stop,size of matrix, and according to that no, of random int will be generated.
i = nmpy.random.randint(1,21,(10,4))
# sum of all the columns
j= i.sum(axis=0)
#axis=1 sum of all the rows
# maximum of 
nmpy.max(i)
# for taking out specific columns , arg= : , means to and from which rows and (0,2,3) means column no, 0,2 and 3
j = i[:2,(0,2,3)]
# access data at particula index
#type(i)
#change back to the list
k= i.ravel()
#knowing the size of the array
i.size
# Out:
# (4, 3)
# 2
# 12
# 40

# %% [markdown]
# # Matplotlib basics

# %%
import matplotlib.pyplot as plt 
import mpl_toolkits.mplot3d as axes3d

# %%
x = nmpy.random.randint(1,5,10)
y = nmpy.random.randint(10,50,10)
z = nmpy.random.randint(30,50,10)
p = nmpy.random.randint(1,5,10)
q = nmpy.random.randint(1,5,10)

# %% [markdown]
# ### For plotting 2d data

# %%
#imput the parameters into it
#plt.plot(x,y) or plt.scatter(x,y)

# for labelng the axis
plt.xlabel('Xaxis')
plt.ylabel('Yaxis')
# for restrictinmg the axis , how much data should be shown : lower and upper limit for x and then lower and upper limit for Y
plt.axis([10,20, 1000,10000])

#show the ghraph
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# figure means area in total within which all the charts/fig1,fig2
#inside argument is figure no, and size
figure1 = plt.figure(1,figsize=(6,4))
#add subplot is used to show where in figure which row and column u want to display the chart, 111 means 1 fig, 1 row, 1 column

ax1 = figure1.add_subplot(121)
ax2=figure1.add_subplot(122)
ax1.plot(x,y)
ax2.plot(p,q)
ax1.set(xlabel='Xaxis',ylabel='yaxis')
plt.show()

# %% [markdown]
# # Panda basics

# %%
import pandas as pd

# %%
file1 = r'C:\Users\Demigod\Documents\Python Project (3D point Cloud)\2019-01-18-10-59-18_Velodyne-VLP-16-Data-WestSideOurBuilding-csv_1To2000 (Frame 0001).csv'

# %%
fileToRead = pd.read_csv(file1)

# %%
fileToRead.rename(columns={'Xaxis': 'X'}, inplace=True)

# %%
# .head will give u top 5 or u can even give parameter inside like 5 or 100 or anything
fileToRead.head()
fileToRead.tail(5)
#returns how many rows are there
print(fileToRead.index)

print('====================================')
# returns how many and which collumns are there
print(fileToRead.columns)
print('====================================')
print(type(fileToRead))
fileToRead.values
#slicing
fileToRead[2:8]
#for picking up column, file.columnname
fileToRead.X
#for multiple column
fileToRead[['X','Y','Z']]
#for accessing particual vaule of a particual column
fileToRead.loc[9,['X']]
# or
fileToRead.loc[5:10,['X']]
#for arithmatic 
fileToRead[fileToRead.X > 1.0]
#or is in 
fileToRead[fileToRead['X'].isin(['1.0','2.0','3.0'])]
#for renaming 
#fileToRead.rename(columns={'X': 'Xaxis'}, inplace=True)
print(fileToRead.columns)
# for all column names rename
#fileToRead.columns = ['xasis','yasis','zasis',]
# Out:
# RangeIndex(start=0, stop=6338, step=1)
# ...
# Index(['Points_m_XYZ:0', 'Points_m_XYZ:1', 'Points_m_XYZ:2', 'X', 'Y', 'Z',
#        'intensity', 'laser_id', 'azimuth', 'distance_m', 'adjustedtime',
#        'timestamp', 'vertical_angle', 'dual_distance', 'dual_intensity',
#        'dual_return_matching'],
#       dtype='object')
# ...
# <class 'pandas.core.frame.DataFrame'>
# Index(['Points_m_XYZ:0', 'Points_m_XYZ:1', 'Points_m_XYZ:2', 'X', 'Y', 'Z',
#        'intensity', 'laser_id', 'azimuth', 'distance_m', 'adjustedtime',
#        'timestamp', 'vertical_angle', 'dual_distance', 'dual_intensity',
#        'dual_return_matching'],
#       dtype='object')
