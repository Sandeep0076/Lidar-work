# %% [markdown]
# # Visualization of 3d Point Cloud
#
#
# ## importing required packages

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
#for z(3rd) axis
import mpl_toolkits.mplot3d as axes3d
#for printing out the selected co ordinate
from mpldatacursor import datacursor 
#for inline 3d graph
# %matplotlib notebook

# %% [markdown]
# ## Reading from the file

# %%
file1 = r'C:\Users\Demigod\Documents\Python Project (3D point Cloud)\2019-01-18-10-59-18_Velodyne-VLP-16-Data-WestSideOurBuilding-csv_1To2000 (Frame 0001).csv'

#Reading the values from CSV file
readfile = pd.read_csv(file1)

#for knowing the Column names to plot the right co ordinate 
readfile.columns
# Out:
# Index(['Points_m_XYZ:0', 'Points_m_XYZ:1', 'Points_m_XYZ:2', 'X', 'Y', 'Z',
#        'intensity', 'laser_id', 'azimuth', 'distance_m', 'adjustedtime',
#        'timestamp', 'vertical_angle', 'dual_distance', 'dual_intensity',
#        'dual_return_matching'],
#       dtype='object')

# %%
##  Storing x,y,z coordinates from respective columns

# %%
xaxis =readfile.X
yaxis =readfile.Y
zaxis =readfile.Z

# %% [markdown]
# ## For plotting the coordinates

# %%
'''def onPick(self, event=None):
        this_point = event.artist
        x_value = this_point.get_xdata()
        y_value = this_point.get_ydata()
        ind = event.ind
        highlight.set_data(x_value[ind][0],y_value[ind][0])
        fig.canvas.draw_idle()
'''

        #setting labels and titles
        

print('Total no. of Points are : ' + str(readfile.shape[0]))

            #print the datapoints when selected from mouse
            #HighlightingDataCursor(xaxis)
            #show the graph
           # plt.show()

figure1 = plt.figure(figsize=(12,10))
    #for positioning and type of projection
fig1 = figure1.add_subplot(111,projection='3d')
fig1.set_title('Visualisation of the Co-ordiantes')
fig1.set_xlabel('X axis')
fig1.set_ylabel('Y axis')
fig1.set_zlabel('Z axis')

    #for type of graph (scatter) and inserting coordinates
selectPoint = fig1.scatter3D(xaxis,yaxis,zaxis)
datacursor(selectPoint)
'''
        highlight, = fig1.plot([], [], 'o', color='yellow')
'''        
plt.show()
'''        cid = plt.connect('pick_event',onPick)
'''
# Out:
# Total no. of Points are : 6338
# <img src="data:image/png;base64,..." width="1200">
# "        cid = plt.connect('pick_event',onPick)\n"
